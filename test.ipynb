# %%
import torch
import numpy as np

from train import main
from utils import process_preds

import matplotlib.pyplot as plt

# %%
valid_loader, captcha_preds, valid_targets = main()
# Out:
# 100%|██████████| 4/4 [00:00<00:00,  4.21it/s, loss=0.019][('4fc36',
#   '%%%%%%%%%%%%44%%%%%%%%%f%%%%%cc%%%%%3%%%%%%%6%%%%%%%%%%%%%%%%%%%%%%%%%%%'),
#  ('fyfbn',
#   '%%%%%%%%%%%%%ff%%%%yy%%%%%%%%f%%%%%bb%%%%%%nn%%%%%%%%%%%%%%%%%%%%%%%%%%%'),
#  ('5mgn4',
#   '%%%%%%%%%%%%55%%%%%m%%%%%%%gg%%%%%%%%n%%%%%%44%%%%%%%%%%%%%%%%%%%%%%%%%%'),
#  ('2mg87',
#   '%%%%%%%%%%%%%22%%%%%m%%%%%%%gg%%%%%%%88%%%%%%%%77%%%%%%%%%%%%%%%%%%%%%%%'),
#  ('gw53m',
#   '%%%%%%%%%%%%gg%%%%%%ww%%%%%%%%%%55%%%%%%33%%%%%%m%%%%%%%%%%%%%%%%%%%%%%%'),
#  ('x2cnn',
#   '%%%%%%%%%%%%%%%%xx%%%%22%%%%%cc%%%%%%n%%%%%%%n%%%%%%%%%%%%%%%%%%%%%%%%%%'),
#  ('7bwm2',
#   '%%%%%%%%%%%%%%77%%%%bb%%%%%%%%ww%%%%%%m%%%%%%%%%%%222%%%%%%%%%%%%%%%%%%%'),
#  ('8684m',
#   '%%%%%%%%%%%%%88%%%%%%66%%%%%%88%%%%%%44%%%%%%m%%%%%%%%%%%%%%%%%%%%%%%%%%'),
#  ('d66cn',
#   '%%%%%%%%%%%%dd%%%%%%%6%%%%%%%66%%%%%%ccc%%%%%n%%%%%%%%%%%%%%%%%%%%%%%%%%'),
#  ('bd3b7',
#   '%%%%%%%%%%%%%b%%%%%%%d%%%%%%33%%%%%%bb%%%%%%%%7%%%%%%%%%%%%%%%%%%%%%%%%%')]

# %%
captcha_texts = process_preds(captcha_preds)

# %%
batch = next(iter(valid_loader))
images = batch['images'].permute(0, 2, 3, 1)[:16]
predictions = captcha_texts[:images.size(0)]
targets = valid_targets[:images.size(0)]

_, axes = plt.subplots(4, 4, figsize=(15, 8))
for image, pred, ax in zip(images, predictions, axes.flatten()):
    ax.imshow(image)
    ax.set_title(f"Prediction: {pred}")
    ax.axis("off")
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
